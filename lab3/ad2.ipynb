# %%
import numpy as np
from math import *

def countField():
    odp = True
    while odp: 
        print('''
        Podaj typ figur, ktore chcesz porownac (np. 1 2):

        1 - kolo
        2 - prostokat
        3 - trojkat
        4 - romb

        5 - koniec
        ''')
        odp = input()
        
        if odp == '1 2':
            print('\nWybrano kolo i prostokat')
            try:
                x = float(input('\nPodaj promien kola: '))
                a = float(input('\nPodaj pierwszy bok prostokata: '))
                b = float(input('\nPodaj drugi bok prostokata: '))
                if x < 0:
                    print('\nPodano ujemna!')
                elif a < 0:
                    print('\nPodano ujemna!')
                elif b < 0:
                    print('\nPodano ujemna!')
                else:
                    polek = pi*(x**2)
                    print('\nPole kola: ', polek)
                    polep = a*b
                    print('\nPole prostokata: ', polep)
                    if polek > polep:
                        print('\nKolo ma wieksze pole')
                    elif polep == polek:
                        print('Pola sa rowne!')
                    else:
                        print('\nProstokat ma wieksze pole')
            except ValueError:
                print('\nWprowadzono zly znak!')
        elif odp == '1 3':
            print('\nWybrano kolo i trojkat')
            try:
                x = float(input('\nPodaj promien kola: '))
                a = float(input('\nPodaj podstawe trojkata: '))
                h = float(input('\nPodaj wysokosc trojkata: '))
                if x < 0:
                    print('\nPodano ujemna!')
                elif a < 0:
                    print('\nPodano ujemna!')
                elif h < 0:
                    print('\nPodano ujemna!')
                else:
                    polek = pi*(x**2) 
                    print('\nPole kola: ', polek)
                    polet = (a*h)/2
                    print('\nPole trojkata:', polet)
                    if polek > polet:
                        print('\nKolo ma wieksze pole')
                    elif polet == polek:
                        print('Pola sa rowne!')
                    else:
                        print('\nTrojkat ma wieksze pole')
            except ValueError:
                print('\nWprowadzono zly znak!')
        elif odp == '1 4':
            print('\nWybrano kolo i romb')
            try:
                x = float(input('\nPodaj promien kola: '))
                d1 = float(input('\nPodaj pierwsza przekatna rombu: '))
                d2 = float(input('\nPodaj druga przekatna rombu: '))
                if x < 0:
                    print('\nPodano ujemna!')
                elif d1 < 0:
                    print('\nPodano ujemna!')
                elif d2 < 0:
                    print('\nPodano ujemna!')
                else:
                    polek = pi*(x**2) 
                    print('\nPole kola: ', polek)
                    poler = (d1*d2)/2
                    print('\nPole rombu:', poler)
                    if polek > poler:
                        print('\nKolo ma wieksze pole')
                    elif polek == poler:
                        print('Pola sa rowne!')
                    else:
                        print('\nRomb ma wieksze pole')
            except ValueError:
                print('\nWprowadzono zly znak!')
        elif odp == '2 1':
            print('\nWybrano kolo i prostokat')
            try:
                x = float(input('\nPodaj promien kola: '))
                a = float(input('\nPodaj pierwszy bok prostokata: '))
                b = float(input('\nPodaj drugi bok prostokata: '))
                if x < 0:
                    print('\nPodano ujemna!')
                elif a < 0:
                    print('\nPodano ujemna!')
                elif b < 0:
                    print('\nPodano ujemna!')
                else:
                    polek = pi*(x**2)
                    print('\nPole kola: ', polek)
                    polep = a*b
                    print('\nPole prostokata: ', polep)
                    if polek > polep:
                        print('\nKolo ma wieksze pole')
                    elif polek == polep:
                        print('Pola sa rowne!')
                    else:
                        print('\nProstokat ma wieksze pole')
            except ValueError:
                print('\nWprowadzono zly znak!')
        elif odp == '2 3':
            print('\nWybrano prostokat i trojkat')
            try:
                a = float(input('\nPodaj pierwszy bok prostokata: '))
                b = float(input('\nPodaj drugi bok prostokata: '))
                pod = float(input('\nPodaj podstawe trojkata: '))
                h = float(input('\nPodaj wysokosc trojkata: '))
                if h < 0:
                    print('\nPodano ujemna!')
                elif a < 0:
                    print('\nPodano ujemna!')
                elif b < 0:
                    print('\nPodano ujemna!')
                elif pod < 0:
                    print('\nPodano ujemna!')
                else:
                    polep = a*b
                    print('\nPole prostokata: ', polep)
                    polet = (pod*h)/2
                    print('\nPole trojkata:', polet)          
                    if polep > polet:
                        print('\nProstokat ma wieksze pole')
                    elif polet == polep:
                        print('Pola sa rowne!')
                    else:
                        print('\nTrojkat ma wieksze pole')
            except ValueError:
                print('\nWprowadzono zly znak!')
        elif odp == '2 4':
            print('\nWybrano prostokat i romb')
            try:
                a = float(input('\nPodaj pierwszy bok prostokata: '))
                b = float(input('\nPodaj drugi bok prostokata: '))
                d1 = float(input('\nPodaj pierwsza przekatna rombu: '))
                d2 = float(input('\nPodaj druga przekatna rombu: '))
                if a < 0:
                    print('\nPodano ujemna!')
                elif b < 0:
                    print('\nPodano ujemna!')
                elif d1 < 0:
                    print('\nPodano ujemna!')
                elif d2 < 0:
                    print('\nPodano ujemna!')
                else:
                    polep = a*b 
                    print('\nPole prostokata: ', polep)
                    poler = (d1*d2)/2
                    print('\nPole rombu:', poler)
                    if polep > poler:
                        print('\nProstokat ma wieksze pole')
                    elif polep == poler:
                        print('Pola sa rowne!')
                    else:
                        print('\nRomb ma wieksze pole')
            except ValueError:
                print('\nWprowadzono zly znak!')
        elif odp == '3 1':
            print('\nWybrano kolo i trojkat')
            try:
                x = float(input('\nPodaj promien kola: '))
                a = float(input('\nPodaj podstawe trojkata: '))
                h = float(input('\nPodaj wysokosc trojkata: '))
                if x < 0:
                    print('\nPodano ujemna!')
                elif a < 0:
                    print('\nPodano ujemna!')
                elif h < 0:
                    print('\nPodano ujemna!')
                else:
                    polek = pi*(x**2) 
                    print('\nPole kola: ', polek)
                    polet = (a*h)/2
                    print('\nPole trojkata:', polet)
                    if polek > polet:
                        print('\nKolo ma wieksze pole')
                    elif polet == polek:
                        print('Pola sa rowne!')
                    else:
                        print('\nTrojkat ma wieksze pole')
            except ValueError:
                print('\nWprowadzono zly znak!')
        elif odp == '3 2':
            print('\nWybrano prostokat i trojkat')
            try:
                a = float(input('\nPodaj pierwszy bok prostokata: '))
                b = float(input('\nPodaj drugi bok prostokata: '))
                pod = float(input('\nPodaj podstawe trojkata: '))
                h = float(input('\nPodaj wysokosc trojkata: '))
                if h < 0:
                    print('\nPodano ujemna!')
                elif a < 0:
                    print('\nPodano ujemna!')
                elif b < 0:
                    print('\nPodano ujemna!')
                elif pod < 0:
                    print('\nPodano ujemna!')
                else:
                    polep = a*b
                    print('\nPole prostokata: ', polep)
                    polet = (pod*h)/2
                    print('\nPole trojkata:', polet)          
                    if polep > polet:
                        print('\nProstokat ma wieksze pole')
                    elif polet == polep:
                        print('Pola sa rowne!')
                    else:
                        print('\nTrojkat ma wieksze pole')
            except ValueError:
                print('\nWprowadzono zly znak!')
        elif odp == '3 4':
            print('\nWybrano trojkat i romb')
            try:
                x = float(input('\nPodaj podstawe trojkata: '))
                y = float(input('\nPodaj wysokosc trojkata: '))
                d1 = float(input('\nPodaj pierwsza przekatna rombu: '))
                d2 = float(input('\nPodaj druga przekatna rombu: '))
                if x < 0:
                    print('\nPodano ujemna!')
                elif y < 0:
                    print('\nPodano ujemna!')
                elif d1 < 0:
                    print('\nPodano ujemna!')
                elif d2 < 0:
                    print('\nPodano ujemna!')
                else:
                    polet = (x*y)/2 
                    print('\nPole trojkata: ', polet)
                    poler = (d1*d2)/2
                    print('\nPole rombu:', poler)
                    if polet > poler:
                        print('\nTrojkat ma wieksze pole')
                    elif polet == poler:
                        print('Pola sa rowne!')
                    else:
                        print('\nRomb ma wieksze pole')
            except ValueError:
                print('\nWprowadzono zly znak!')
        elif odp == '4 1':
            print('\nWybrano kolo i romb')
            try:
                x = float(input('\nPodaj promien kola: '))
                d1 = float(input('\nPodaj pierwsza przekatna rombu: '))
                d2 = float(input('\nPodaj druga przekatna rombu: '))
                if x < 0:
                    print('\nPodano ujemna!')
                elif d1 < 0:
                    print('\nPodano ujemna!')
                elif d2 < 0:
                    print('\nPodano ujemna!')
                else:
                    polek = pi*(x**2) 
                    print('\nPole kola: ', polek)
                    poler = (d1*d2)/2
                    print('\nPole rombu:', poler)
                    if polek > poler:
                        print('\nKolo ma wieksze pole')
                    elif polek == poler:
                        print('Pola sa rowne!')
                    else:
                        print('\nRomb ma wieksze pole')
            except ValueError:
                print('\nWprowadzono zly znak!')
        elif odp == '4 2':
            print('\nWybrano prostokat i romb')
            try:
                a = float(input('\nPodaj pierwszy bok prostokata: '))
                b = float(input('\nPodaj drugi bok prostokata: '))
                d1 = float(input('\nPodaj pierwsza przekatna rombu: '))
                d2 = float(input('\nPodaj druga przekatna rombu: '))
                if a < 0:
                    print('\nPodano ujemna!')
                elif b < 0:
                    print('\nPodano ujemna!')
                elif d1 < 0:
                    print('\nPodano ujemna!')
                elif d2 < 0:
                    print('\nPodano ujemna!')
                else:
                    polep = a*b 
                    print('\nPole prostokata: ', polep)
                    poler = (d1*d2)/2
                    print('\nPole rombu:', poler)
                    if polep > poler:
                        print('\nProstokat ma wieksze pole')
                    elif polep == poler:
                        print('Pola sa rowne!')
                    else:
                        print('\nRomb ma wieksze pole')
            except ValueError:
                print('\nWprowadzono zly znak!')
        elif odp == '4 3':
            print('\nWybrano trojkat i romb')
            try:
                x = float(input('\nPodaj podstawe trojkata: '))
                y = float(input('\nPodaj wysokosc trojkata: '))
                d1 = float(input('\nPodaj pierwsza przekatna rombu: '))
                d2 = float(input('\nPodaj druga przekatna rombu: '))
                if x < 0:
                    print('\nPodano ujemna!')
                elif y < 0:
                    print('\nPodano ujemna!')
                elif d1 < 0:
                    print('\nPodano ujemna!')
                elif d2 < 0:
                    print('\nPodano ujemna!')
                else:
                    polet = (x*y)/2 
                    print('\nPole trojkata: ', polet)
                    poler = (d1*d2)/2
                    print('\nPole rombu:', poler)
                    if polet > poler:
                        print('\nTrojkat ma wieksze pole')
                    elif polet == poler:
                        print('Pola sa rowne!')
                    else:
                        print('\nRomb ma wieksze pole')
            except ValueError:
                print('\nWprowadzono zly znak!')
        elif odp == '5':
            odp = False
        else:
            print('\nZly znak!')

countField()
# Out:
#         Podaj typ figur, ktore chcesz porownac (np. 1 2):
#
#         1 - kolo
#         2 - prostokat
#         3 - trojkat
#         4 - romb
#
#         5 - koniec
#
# 3 4
#
# Wybrano trojkat i romb
#
# Podaj podstawe trojkata: 5
#
# Podaj wysokosc trojkata: 5
#
# Podaj pierwsza przekatna rombu: 5
#
# Podaj druga przekatna rombu: 5
#
# Pole trojkata:  12.5
#
# Pole rombu: 12.5
# Pola sa rowne!
#
#         Podaj typ figur, ktore chcesz porownac (np. 1 2):
#
#         1 - kolo
#         2 - prostokat
#         3 - trojkat
#         4 - romb
#
#         5 - koniec
#
# 5
